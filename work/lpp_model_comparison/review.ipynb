# %% [markdown]
# # Review pooled LPP model comparison
#
# Aggregate the returned fits only after every expected fit, simulation, and diagnostic is present.

# %%
from lpp_ecmr.model_comparison_workflow import review_results

comparison = review_results()
comparison
