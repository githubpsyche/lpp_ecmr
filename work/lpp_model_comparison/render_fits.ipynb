# %% [markdown]
# # Prepare pooled LPP model-comparison fits
#
# Generate one cluster-ready notebook for each of the 16 models without running any fit.

# %%
jaxcmr_root = ""  # optional path to a jaxcmr checkout

# %%
from lpp_ecmr.model_comparison_workflow import prepare_work_unit

manifest = prepare_work_unit(jaxcmr_root or None)
manifest
