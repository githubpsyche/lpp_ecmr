# %%
import os
import papermill as pm
from jaxcmr.helpers import find_project_root
from lpp_ecmr.data_contract import MIXED_TRIAL_QUERY
from IPython.display import Image, display
from matplotlib import rcParams  # type: ignore

# %% [markdown]
# # Render Reference Analyses
#
# Render categorized descriptive analyses for the Talmi EEG project. This work unit prepares notebooks from the colocated analysis templates and writes its reference figures here.

# %%
base_params = {
    "data_name": "TalmiEEG",
    "data_query": MIXED_TRIAL_QUERY,
    "category_field": "condition",
    "contrast_name": "Source",
    "category_values": [1, 2],
    "labels": ["Negative", "Neutral"],
    "color_cycle": ["red", "black"],
    "ylim": [0.2, .8],
    "output_path": "work/reference_analyses/reference_catspc.png",
}

output_path = f"{find_project_root()}/work/reference_analyses/rendered_cat_spc.ipynb"
print(output_path)
pm.execute_notebook(
    f"{find_project_root()}/work/reference_analyses/cat_spc.ipynb",
    output_path,
    parameters=base_params,
    progress_bar=False,
    prepare_only=True,
)

print(f"![]({base_params['output_path']})")
display(Image(filename=os.path.join(find_project_root(), base_params["output_path"]), width=600))

# %% [markdown]
# # Categorized LPP by Study Position
#
# Plot LPP amplitude by study position, factored by categorical features (e.g., emotion tags).

# %%
base_params = {
    "data_name": "TalmiEEG",
    "data_query": MIXED_TRIAL_QUERY,
    "category_field": "condition",
    "category_values": [1, 2],
    "labels": ["Negative", "Neutral"],
    "color_cycle": ["red", "black"],
    "ylim": [-.1, 1.5],
    "output_path": "work/reference_analyses/cat_lpp_spc_{}.png",
}

for lpp_field in ["EarlyLPP", "LateLPP"]:
    output_path = base_params["output_path"].format(lpp_field)
    print(output_path)
    pm.execute_notebook(
        f"{find_project_root()}/work/reference_analyses/cat_lpp_spc.ipynb",
        f"{find_project_root()}/work/reference_analyses/rendered_cat_lpp_spc_{lpp_field}.ipynb",
        parameters=base_params | {
            "lpp_field": lpp_field,
            "output_path": output_path,
        },
        progress_bar=False,
        prepare_only=True,
    )
    print(f"![]({output_path})")
    display(Image(filename=os.path.join(find_project_root(), output_path), width=600))

# %% [markdown]
# # Categorized Recall Rate by LPP
#
# Plot the recall rate as a function of binned LPP amplitude for different categories.

# %%
base_params = {
    "data_name": "TalmiEEG",
    "data_query": MIXED_TRIAL_QUERY,
    "category_field": "condition",
    "category_values": [1, 2],
    "labels": ["Negative", "Neutral"],
    "color_cycle": ["red", "black"],
    "ylim": [0, 1.0],
    "output_path": "work/reference_analyses/cat_recall_by_lpp_{}.png",
}

for lpp_field in ["EarlyLPP", "LateLPP"]:
    output_path = base_params["output_path"].format(lpp_field)
    print(output_path)
    pm.execute_notebook(
        f"{find_project_root()}/work/reference_analyses/cat_recall_by_lpp.ipynb",
        f"{find_project_root()}/work/reference_analyses/rendered_cat_recall_by_lpp_{lpp_field}.ipynb",
        parameters=base_params | {
            "lpp_field": lpp_field,
            "output_path": output_path,
        },
        progress_bar=False,
        prepare_only=True,
    )
    print(f"![]({output_path})")
    display(Image(filename=os.path.join(find_project_root(), output_path), width=600))

    print(f"![]({output_path.replace('.png', '_counts.png')})")
    display(Image(filename=os.path.join(find_project_root(), output_path.replace(".png", "_counts.png")), width=600))

# %% [markdown]
# # Categorized LPP by Recall Status
# Plot the LPP amplitudes for items of a given category, separated by whether they were later recalled or not.

# %%
base_params = {
    "data_name": "TalmiEEG",
    "data_query": MIXED_TRIAL_QUERY,
    "category_field": "condition",
    "labels": ["Recalled", "Unrecalled"],
    "ylim": [-.6, 2.2],
    "output_path": "work/reference_analyses/cat_lpp_by_recall_{}_{}.png",
}

for lpp_field in ["EarlyLPP", "LateLPP"]:
    color_cycle = [each["color"] for each in rcParams["axes.prop_cycle"]]

    for category_value, contrast_name in zip([1, 2], ["Negative", "Neutral"]):
        output_path = base_params["output_path"].format(lpp_field, contrast_name)
        pm.execute_notebook(
            f"{find_project_root()}/work/reference_analyses/cat_lpp_by_recall.ipynb",
            f"{find_project_root()}/work/reference_analyses/rendered_cat_lpp_by_recall_{lpp_field}_{contrast_name}.ipynb",
            parameters=base_params | {
                "category_value": category_value,
                "contrast_name": contrast_name,
                "lpp_field": lpp_field,
                "output_path": output_path,
                "color_cycle": [color_cycle.pop(0), color_cycle.pop(0)],
            },
            progress_bar=False,
            prepare_only=True,
        )
        print(f"![]({output_path})")
        display(Image(filename=os.path.join(find_project_root(), output_path), width=600))
