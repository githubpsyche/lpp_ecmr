# %% [markdown]
# # Render Model Comparison: Exclude-Termination Likelihood
#
# Compare models fitted with `ExcludeTerminationLikelihoodFnGenerator` (recall items only, ignoring when recall stopped).

# %%
import os
import papermill as pm

_here = os.path.dirname(os.path.abspath("__file__"))
_lpp_ecmr = os.path.dirname(_here)
_workspace = os.path.dirname(_lpp_ecmr)

template = os.path.join(_workspace, "jaxcmr", "templates", "model_comparison.ipynb")

# %%
_ft = "50_set_likelihood_fixed_term_best_of_3"
_ecmr_ft = "50_set_likelihood_best_of_3"

params = {
    "data_names": ["TalmiEEG"],
    "fit_dir": "fits/",
    "table_dir": "tables",
    "run_tag": "Exclude_Termination",
    "use_aicc": False,
    "data_path": "",
    "trial_query": "",
    "model_class_names": [
        "CMR", "LPP_CMR",
        "eCMR", "LPP_eCMR",
    ],
    "model_display_titles": [
        "CMR", "LPP-CMR",
        "eCMR", "LPP-eCMR",
    ],
    "model_fit_tags": [_ft, _ft, _ecmr_ft, _ecmr_ft],
    "nesting_pairs": [
        ["CMR", "LPP-CMR"],
        ["eCMR", "LPP-eCMR"],
    ],
    "query_parameters": [
        "encoding_drift_rate", "start_drift_rate", "recall_drift_rate",
        "shared_support", "item_support", "learning_rate",
        "primacy_scale", "primacy_decay", "choice_sensitivity",
        "emotion_scale", "lpp_main_scale", "lpp_inter_scale",
    ],
    "dataset_groups": {},
}

output = os.path.join(_here, "rendered", "model_comparison_exclude_termination.ipynb")
os.makedirs(os.path.dirname(output), exist_ok=True)
print(output)

pm.execute_notebook(template, output, parameters=params, cwd=_lpp_ecmr, progress_bar=True)
